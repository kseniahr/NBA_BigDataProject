# %%
import glob
import os
import pandas as pd

# %%
players = pd.read_csv('./players.csv')

# %%
players.head()
# Out:
#    #Date/Time of Update: 2017-05-09 4:34:01 PM  #Player ID #LastName  \
# 0                                          NaN       10138   Abrines
# 1                                          NaN        9466       Acy
# 2                                          NaN        9390     Adams
# 3                                          NaN        9375   Afflalo
# 4                                          NaN        9357    Ajinca
#
#   #FirstName  #Jersey Num #Position #Height  #Weight #Birth Date  #Age  ...  \
# 0       Alex          8.0         F    6'6"    190.0    8/1/1993  23.0  ...
# 1     Quincy          4.0        PF    6'7"    240.0   10/6/1990  26.0  ...
# 2     Steven         12.0         C    7'0"    255.0   7/20/1993  23.0  ...
# 3      Arron         40.0        SG    6'5"    215.0  10/15/1985  31.0  ...
# 4     Alexis         42.0         C    7'2"    248.0    5/6/1988  29.0  ...
#
#   #Team Abbr     #Team City #Team Name  #GamesPlayed #Fg2PtAtt #Fg2PtMade  \
# ...

# %%
players = players.iloc[:,1:]

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 23 columns):
# #Player ID        517 non-null int64
# #LastName         517 non-null object
# #FirstName        517 non-null object
# #Jersey Num       493 non-null float64
# #Position         517 non-null object
# #Height           510 non-null object
# #Weight           510 non-null float64
# #Birth Date       508 non-null object
# #Age              508 non-null float64
# #Birth City       219 non-null object
# #Birth Country    228 non-null object
# #Rookie           517 non-null object
# #Team ID          517 non-null int64
# #Team Abbr        517 non-null object
# #Team City        517 non-null object
# #Team Name        517 non-null object
# #GamesPlayed      517 non-null int64
# #Fg2PtAtt         517 non-null int64
# #Fg2PtMade        517 non-null int64
# #Fg3PtAtt         517 non-null int64
# #Fg3PtMade        517 non-null int64
# #FtAtt            517 non-null int64
# ...

# %%
players['full_name'] = players['#FirstName'] + " " + players['#LastName']

# %%
players.drop(['#FirstName','#LastName'],axis=1,inplace=True)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 22 columns):
# #Player ID        517 non-null int64
# #Jersey Num       493 non-null float64
# #Position         517 non-null object
# #Height           510 non-null object
# #Weight           510 non-null float64
# #Birth Date       508 non-null object
# #Age              508 non-null float64
# #Birth City       219 non-null object
# #Birth Country    228 non-null object
# #Rookie           517 non-null object
# #Team ID          517 non-null int64
# #Team Abbr        517 non-null object
# #Team City        517 non-null object
# #Team Name        517 non-null object
# #GamesPlayed      517 non-null int64
# #Fg2PtAtt         517 non-null int64
# #Fg2PtMade        517 non-null int64
# #Fg3PtAtt         517 non-null int64
# #Fg3PtMade        517 non-null int64
# #FtAtt            517 non-null int64
# #FtMade           517 non-null int64
# full_name         517 non-null object
# ...

# %%
players.rename(columns={
    '#Player ID':'player_id',
    '#Jersey Num':'jersey_number',
    '#Position':'position',
    '#Height':'height',
    '#Weight':'weight',
    '#Age':'age',
    '#Birth Date':'birthdate',
    '#Birth City':'birth_city',
    '#Birth Country':'birth_country',
    '#Rookie':'rookie',
    '#Team ID':'team_id',
    '#Team Abbr':'team_abbr',
    '#Team City':'team_city',
    '#Team Name':'team_name',
    '#GamesPlayed':'games_played',
    '#Fg2PtAtt':'fg2_pt_att',
    '#Fg2PtMade':'fg2_pt_made',
    '#Fg3PtAtt':'fg3_pt_att',
    '#Fg3PtMade':'fg3_pt_made',
    '#FtAtt':'ft_att',
    '#FtMade':'ft_made',
},inplace=True)

# %%
players
# Out:
#            jersey_number position height  weight   birthdate   age  \
# player_id
# 10138                8.0        F   6'6"   190.0    8/1/1993  23.0
# 9466                 4.0       PF   6'7"   240.0   10/6/1990  26.0
# 9390                12.0        C   7'0"   255.0   7/20/1993  23.0
# 9375                40.0       SG   6'5"   215.0  10/15/1985  31.0
# 9357                42.0        C   7'2"   248.0    5/6/1988  29.0
# 9272                45.0        C  6'11"   245.0  10/31/1988  28.0
# 9480                12.0       PF  6'11"   240.0   7/19/1985  31.0
# 9454                34.0       PF   6'8"   245.0  11/15/1995  21.0
# 9254                 5.0       PF   6'9"   255.0    2/4/1989  28.0
# 9299                 9.0       SG   6'4"   213.0   1/11/1982  35.0
# 9452                 8.0       SF   6'9"   215.0   9/21/1990  26.0
# 9297                 7.0        C  6'10"   245.0    7/6/1978  38.0
# 9527                26.0       SG   6'6"   220.0  10/16/1982  34.0
# ...

# %%
players.set_index('player_id',inplace=True)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 10138 to 10169
# Data columns (total 21 columns):
# jersey_number    493 non-null float64
# position         517 non-null object
# height           510 non-null object
# weight           510 non-null float64
# birthdate        508 non-null object
# age              508 non-null float64
# birth_city       219 non-null object
# birth_country    228 non-null object
# rookie           517 non-null object
# team_id          517 non-null int64
# team_abbr        517 non-null object
# team_city        517 non-null object
# team_name        517 non-null object
# games_played     517 non-null int64
# fg2_pt_att       517 non-null int64
# fg2_pt_made      517 non-null int64
# fg3_pt_att       517 non-null int64
# fg3_pt_made      517 non-null int64
# ft_att           517 non-null int64
# ft_made          517 non-null int64
# full_name        517 non-null object
# dtypes: float64(3), int64(8), object(10)
# memory usage: 88.9+ KB

# %%
players.head()
# Out:
#            jersey_number position height  weight   birthdate   age  \
# player_id
# 10138                8.0        F   6'6"   190.0    8/1/1993  23.0
# 9466                 4.0       PF   6'7"   240.0   10/6/1990  26.0
# 9390                12.0        C   7'0"   255.0   7/20/1993  23.0
# 9375                40.0       SG   6'5"   215.0  10/15/1985  31.0
# 9357                42.0        C   7'2"   248.0    5/6/1988  29.0
#
#                   birth_city birth_country rookie  team_id  ...  \
# player_id                                                   ...
# 10138      Palma de Mallorca         Spain      Y       96  ...
# 9466               Tyler, TX           USA      N       84  ...
# 9390                 Rotorua    NewZealand      N       96  ...
# 9375         Los Angeles, CA           USA      N      103  ...
# 9357           Saint-?tienne        France      N      110  ...
#
#                team_city team_name games_played  fg2_pt_att  fg2_pt_made  \
# player_id
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 10138 to 10169
# Data columns (total 21 columns):
# jersey_number    493 non-null float64
# position         517 non-null object
# height           510 non-null object
# weight           510 non-null float64
# birthdate        508 non-null object
# age              508 non-null float64
# birth_city       219 non-null object
# birth_country    228 non-null object
# rookie           517 non-null object
# team_id          517 non-null int64
# team_abbr        517 non-null object
# team_city        517 non-null object
# team_name        517 non-null object
# games_played     517 non-null int64
# fg2_pt_att       517 non-null int64
# fg2_pt_made      517 non-null int64
# fg3_pt_att       517 non-null int64
# fg3_pt_made      517 non-null int64
# ft_att           517 non-null int64
# ft_made          517 non-null int64
# full_name        517 non-null object
# dtypes: float64(3), int64(8), object(10)
# memory usage: 88.9+ KB

# %%
players.drop(['height','weight','birth_city','birth_country'],axis=1,inplace=True)

# %%
players
# Out:
#            jersey_number position   birthdate   age rookie  team_id team_abbr  \
# player_id
# 10138                8.0        F    8/1/1993  23.0      Y       96       OKL
# 9466                 4.0       PF   10/6/1990  26.0      N       84       BRO
# 9390                12.0        C   7/20/1993  23.0      N       96       OKL
# 9375                40.0       SG  10/15/1985  31.0      N      103       SAC
# 9357                42.0        C    5/6/1988  29.0      N      110       NOP
# 9272                45.0        C  10/31/1988  28.0      N      100       MIN
# 9480                12.0       PF   7/19/1985  31.0      N      106       SAS
# 9454                34.0       PF  11/15/1995  21.0      N       95       ORL
# 9254                 5.0       PF    2/4/1989  28.0      N       87       IND
# 9299                 9.0       SG   1/11/1982  35.0      N      107       MEM
# 9452                 8.0       SF   9/21/1990  26.0      N       97       POR
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 10138 to 10169
# Data columns (total 17 columns):
# jersey_number    493 non-null float64
# position         517 non-null object
# birthdate        508 non-null object
# age              508 non-null float64
# rookie           517 non-null object
# team_id          517 non-null int64
# team_abbr        517 non-null object
# team_city        517 non-null object
# team_name        517 non-null object
# games_played     517 non-null int64
# fg2_pt_att       517 non-null int64
# fg2_pt_made      517 non-null int64
# fg3_pt_att       517 non-null int64
# fg3_pt_made      517 non-null int64
# ft_att           517 non-null int64
# ft_made          517 non-null int64
# full_name        517 non-null object
# dtypes: float64(2), int64(8), object(7)
# memory usage: 92.7+ KB

# %%
players.to_csv('./players_dataframe.csv', header=False)
